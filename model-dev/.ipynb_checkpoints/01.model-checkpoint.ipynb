# %% [markdown]
# # Software instillation

# %%
# !sudo apt-get install unzip
# !sudo apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-25ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   unrar
# 0 upgraded, 1 newly installed, 0 to remove and 6 not upgraded.
# Need to get 113 kB of archives.
# After this operation, 406 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 unrar amd64 1:5.6.6-2build1 [113 kB]
# Fetched 113 kB in 1s (94.4 kB/s)
# Selecting previously unselected package unrar.
# (Reading database ... 272556 files and directories currently installed.)
# Preparing to unpack .../unrar_1%3a5.6.6-2build1_amd64.deb ...
# Unpacking unrar (1:5.6.6-2build1) ...
# Setting up unrar (1:5.6.6-2build1) ...
# update-alternatives: using /usr/bin/unrar-nonfree to provide /usr/bin/unrar (unrar) in auto mode
# Processing triggers for man-db (2.9.1-1) ...

# %% [markdown]
# # Download datasets

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=162GILn3wYAzVEoE6KrCVq-i2HwepD5a5' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=162GILn3wYAzVEoE6KrCVq-i2HwepD5a5" -O raw.rar && rm -rf /tmp/cookies.txt
# !wget https://drive.google.com/file/d/1ULqYtd9yomeGz53WBhgRdPRFB37ppeDU/view
# !unrar e raw.rar raw/images/
# Out:
# --2023-01-20 23:28:26--  https://docs.google.com/uc?export=download&confirm=t&id=162GILn3wYAzVEoE6KrCVq-i2HwepD5a5
# Resolving docs.google.com (docs.google.com)... 142.250.183.174, 2404:6800:4009:825::200e
# Connecting to docs.google.com (docs.google.com)|142.250.183.174|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5852c39q70fkcor9vbk4vhcdrftbk04o/1674257250000/07007235838582553008/*/162GILn3wYAzVEoE6KrCVq-i2HwepD5a5?e=download&uuid=bd8c4c12-2dff-4203-bd88-83ce2242bd86 [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-20 23:28:27--  https://doc-0c-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5852c39q70fkcor9vbk4vhcdrftbk04o/1674257250000/07007235838582553008/*/162GILn3wYAzVEoE6KrCVq-i2HwepD5a5?e=download&uuid=bd8c4c12-2dff-4203-bd88-83ce2242bd86
# Resolving doc-0c-1c-docs.googleusercontent.com (doc-0c-1c-docs.googleusercontent.com)... 172.217.166.33, 2404:6800:4009:81f::2001
# Connecting to doc-0c-1c-docs.googleusercontent.com (doc-0c-1c-docs.googleusercontent.com)|172.217.166.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2346095617 (2.2G) [application/rar]
# Saving to: ‘raw.rar’
#
# raw.rar             100%[===================>]   2.18G  16.6MB/s    in 2m 40s
#
# 2023-01-20 23:31:08 (14.0 MB/s) - ‘raw.rar’ saved [2346095617/2346095617]
#
# --2023-01-20 23:31:08--  https://drive.google.com/file/d/1ULqYtd9yomeGz53WBhgRdPRFB37ppeDU/view
# Resolving drive.google.com (drive.google.com)... 142.250.66.14, 2404:6800:4009:823::200e
# Connecting to drive.google.com (drive.google.com)|142.250.66.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view’
#
# view                    [ <=>                ]  71.35K  --.-KB/s    in 0.02s
#
# 2023-01-20 23:31:09 (3.54 MB/s) - ‘view’ saved [73060]
#
#
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from raw.rar
#
# Creating    raw                                                       OK
# Creating    raw/images                                                OK
# Extracting  raw/images/000b0fd767c5ab2656b7ed8d43674777.jpg              0  OK
# Extracting  raw/images/000ed1547634a24f09f22530065d46c9.jpg              0  OK
# Extracting  raw/images/0011b4d3f9068a9efbb84dc3157b76c9.jpg              0  OK
# Extracting  raw/images/0019a9ab6fd5ef3df915241bc323afb5.jpg              0  OK
# Extracting  raw/images/00349ffee00a2ce026ffb36e4e37caab.jpg              0  OK
# Extracting  raw/images/004a08c20af8b043a5a1cdfc6a01b48a.jpg              0  OK
# Extracting  raw/images/00521f6fd0d749c9601a55eb8cf7533e.jpg              0  OK
# Extracting  raw/images/00527ced822bed10c572ba797846ac4c.jpg              0  OK
# Extracting  raw/images/00654503e1204235de86e81d948d0562.jpg              0  OK
# Extracting  raw/images/006e04a34f54d116f6aff2bb31cb320c.jpg              0  OK
# Extracting  raw/images/006e70d6a51af3e670bbe712a83aa1c5.jpg              0  OK
# Extracting  raw/images/00747f635a27ba324bf63b3d63d608e1.jpg              0  OK
# Extracting  raw/images/00777add05cbc205d216d5b502706c8a.jpg              0  OK
# Extracting  raw/images/007e06c0407b54ac0b971d3994c9cd88.jpg              0  OK
# Extracting  raw/images/00806f5a86377b0945f13b66b109708f.jpg              0  OK
# Extracting  raw/images/0081af04e33fda23cb1d2da07b994200.jpg              0  OK
# Extracting  raw/images/0081b25823f23a536c9f1952491db636.jpg              0  OK
# Extracting  raw/images/008f4a55a58faa61e70e1a6cc45b1fb8.jpg              0  OK
# Extracting  raw/images/009a1abeed7ed3348768b8f2bb58b6ad.jpg              0  OK
# Extracting  raw/images/00b3b796ce8512d228db5bc129049b19.jpg              0  OK
# Extracting  raw/images/00b48429c1382cc7d1c72926acedbaa7.jpg              0  OK
# Extracting  raw/images/00b5bf7dce31145b95ef3adb89a99b03.jpg              0  OK
# Extracting  raw/images/00b5fc2d3153637e65a35363295e14ba.jpg              0  OK
# Extracting  raw/images/00bb84f0f10393189e229e52f4b2f652.jpg              0  OK
# Extracting  raw/images/00bce25b1d3a3422bb366a12e3e9ac6a.jpg              0  OK
# Extracting  raw/images/00c712f2b980052499567e72e70a5b2f.jpg              0  OK
# Extracting  raw/images/00d94c51444ae4b99e598c94cceb3ba4.jpg              0  OK
# Extracting  raw/images/00dae25f50802c09639f97b2dec7dca5.jpg              0  OK
# Extracting  raw/images/00df7d46d661eba176ccc167f2763585.jpg              0  OK
# Extracting  raw/images/00dfd4598684d7d0914304ab05719ef7.jpg              0  OK
# Extracting  raw/images/00e0bbdd7eecd9e53d31312e674e6d83.jpg              0  OK
# Extracting  raw/images/00e6e7833a17108274aa01275cafcaa9.jpg              0  OK
# Extracting  raw/images/00f079ed418b1cb2cfb5aa2d11dfea03.jpg              0  OK
# Extracting  raw/images/00f12b9ba667d2c9e60aabf56afc5c6c.jpg              0  OK
# Extracting  raw/images/00f54ee82124ff35d346d15145475ab4.jpg              0  OK
# Extracting  raw/images/00f6cb1c7473f12ea482dceaad648470.jpg              0  OK
# Extracting  raw/images/03ea809773b3e96af83efff9b6182d98.jpg              1  OK
# Extracting  raw/images/03eab36eff5829fe7c8fcc12ef0db6fe.jpg              1  OK
# Extracting  raw/images/03fbdf92cb1367b06153d00d1651118c.jpg              1  OK
# Extracting  raw/images/04080667ad21bb9e5abdcee5c59023c9.jpg              1  OK
# Extracting  raw/images/040c3caa8aa34fe60e16e15e2695eb80.jpg              1  OK
# Extracting  raw/images/04164eada29df1190caaa980bfb6d38e.jpg              1  OK
# Extracting  raw/images/041f2a0fe411e46241675f617383a058.jpg              1  OK
# Extracting  raw/images/042098ad310722552bf7a2e41834e3bf.jpg              1  OK
# Extracting  raw/images/04210994b792641e97f4c4a57f545218.jpg              1  OK
# Extracting  raw/images/0422d536e5855168fa4d2f8fda42a88e.jpg              1  OK
# Extracting  raw/images/0429a62696acb02201ee3008144372af.jpg              1  OK
# Extracting  raw/images/042f80a731d4d907f4f2eeab1e309efc.jpg              1  OK
# Extracting  raw/images/04308179e509e34ab757f8458af858ab.jpg              1  OK
# Extracting  raw/images/0437989fdcc7de4565e83fed15f378f2.jpg              1  OK
# Extracting  raw/images/0444b70bd974141ed18302c314383836.jpg              1  OK
# Extracting  raw/images/0450fc05a731b77d11766a2cd4ada1b0.jpg              1  OK
# Extracting  raw/images/04628a85eef965e352e31c0fc892d61a.jpg              1  OK
# Extracting  raw/images/0465f2c6a9e531869e0d3674594edbb2.jpg              1  OK
# Extracting  raw/images/0467c96c6eabf70383ce58b4dece0300.jpg              1  OK
# Extracting  raw/images/047ff0e021b70b642c192aae971c5cad.jpg              1  OK
# Extracting  raw/images/04850b4c78062d7195d93fd587514f8e.jpg              1  OK
# Extracting  raw/images/04890985ffabdeb0c2a708f3111c33bb.jpg              1  OK
# Extracting  raw/images/04924cb120fe517e9cb3ba0005792355.jpg              1  OK
# Extracting  raw/images/04a4e544abd09d3aefb72c6116896e02.jpg              1  OK
# Extracting  raw/images/04c74fb6ff31ac072c204d468ae5b7de.jpg              1  OK
# Extracting  raw/images/04c91af1de235820d962c6f2325ab410.jpg              1  OK
# Extracting  raw/images/04cb2c91b672e35ea72bfd15edfbbd60.jpg              1  OK
# Extracting  raw/images/04cd438cdc846274a335be78fc18a25f.jpg              1  OK
# Extracting  raw/images/04dc5a12c2a385ab131b7a62e845b624.jpg              1  OK
# Extracting  raw/images/04df27bdf59becdb480d4398536abd35.jpg              1  OK
# Extracting  raw/images/04e738e28cf11ed560f5e7cc503ceb3e.jpg              1  OK
# Extracting  raw/images/04f608113986eac77ef87bb8dfb9ea34.jpg              1  OK
# Extracting  raw/images/05006c41c5fbafc5b3010083dc90eb4b.jpg              1  OK
# Extracting  raw/images/0503d3670b8e805bc1205ca1c8eaa316.jpg              1  OK
# Extracting  raw/images/050b82ff23c9449b7cc7cf12706cbd2d.jpg              1  OK
# Extracting  raw/images/050cc90602fa408ea79e0ae889f542c4.jpg              1  OK
# Extracting  raw/images/051a43d369a43dcdd723d70fbec00fc8.jpg              1  OK
# Extracting  raw/images/0527610dd59871371fe8616426b3fcf4.jpg              1  OK
# Extracting  raw/images/0527dd2286a12e130b53287e6740c7b9.jpg              1  OK
# Extracting  raw/images/052c59d8d4fbafda23fcd178e89b4d4a.jpg              1  OK
# Extracting  raw/images/05340fbca3ae9816f56a950e8985519f.jpg              1  OK
# Extracting  raw/images/053b6906c62d6fdb2cc7c7150413813a.jpg              1  OK
# Extracting  raw/images/053d4e9e51ac3a2c944f2c252a089754.jpg              1  OK
# Extracting  raw/images/053db9f8b9a5cd86704d4d03388a234c.jpg              1  OK
# Extracting  raw/images/0542ab55a203b8f1597efc3734aff9c1.jpg              1  OK
# Extracting  raw/images/0543a0c0b6fee43ec27d99cccc54961a.jpg              1  OK
# Extracting  raw/images/054994c71b8253732326391d09578f68.jpg              1  OK
# Extracting  raw/images/054c3c89237513e1ed6ef361175fae30.jpg              1  OK
# Extracting  raw/images/055f975c73af31b07d8a86bb7a64fd84.jpg              1  OK
# Extracting  raw/images/0560cd977021e78f9136e22d53d95268.jpg              1  OK
# Extracting  raw/images/05617c4bd3df79447165842ad3627493.jpg              1  OK
# Extracting  raw/images/056b0b16c637a63492aecaa8399472a1.jpg              1  OK
# Extracting  raw/images/0585c3c055bae2f1442f55ad28c805fd.jpg              1  OK
# Extracting  raw/images/0588e72d3887b84ebab9351e6482b880.jpg              1  OK
# Extracting  raw/images/059f9c9fc7caffa01e85d7bbed2dab07.jpg              1  OK
# Extracting  raw/images/05a0243a9649af5a8249fd7cd3adac3e.jpg              1  OK
# Extracting  raw/images/05aed6343f0e9f082df7b36a35e81b9e.jpg              2  OK
# Extracting  raw/images/05b577def508111e0c0d4fd72ca8e5b4.jpg              2  OK
# Extracting  raw/images/05b9d238c199dd6c831e2072636c952b.jpg              2  OK
# Extracting  raw/images/05c1ca4dedf6076598a36630ff5c7091.jpg              2  OK
# Extracting  raw/images/05c36ef35c9ebcc4594681516d0356e8.jpg              2  OK
# Extracting  raw/images/05c430b123cc07cfc838d7d06b210b4f.jpg              2  OK
# Extracting  raw/images/05c58c3f3aebf576044cba22d195f84e.jpg              2  OK
# Extracting  raw/images/05d31f98c05747a82dd3d53e6f58ef2e.jpg              2  OK
# Extracting  raw/images/05d33c5af5ca0de5cdc463bd46f0d7c1.jpg              2  OK
# Extracting  raw/images/05d460dbde7de11bbbb92ed16b536609.jpg              2  OK
# Extracting  raw/images/05de96481dbc4e99f086a1b2315d3a66.jpg              2  OK
# Extracting  raw/images/05edd3d39de7161ab910d85386d53c30.jpg              2  OK
# Extracting  raw/images/05ef86d6de0f145edcf9f724e0cfb454.jpg              2  OK
# Extracting  raw/images/05f7748046f5a6878e3057f5afdf3094.jpg              2  OK
# Extracting  raw/images/05fa27f3d9e4f9adda9d6a168c138857.jpg              2  OK
# Extracting  raw/images/05fc223f3a877408091a2e78f0c3ee9b.jpg              2  OK
# Extracting  raw/images/060125a37f54e1d4da73b5a308cff5e0.jpg              2  OK
# Extracting  raw/images/0603f49d6953d25b724b166d191b8ea3.jpg              2  OK
# Extracting  raw/images/060a2994c6e1d3e22e18fa84b5a91714.jpg              2  OK
# Extracting  raw/images/063a6022eb9ff9f74f15740cab410887.jpg              2  OK
# Extracting  raw/images/063bfc1148835b0288abbeb29105e183.jpg              2  OK
# Extracting  raw/images/063e750e60b2690c3afc445fd4bbf0a7.jpg              2  OK
# Extracting  raw/images/06455188438cb3dd486f3e0436929ad5.jpg              2  OK
# Extracting  raw/images/06455e095c2a8e70e4855171cd175c08.jpg              2  OK
# Extracting  raw/images/0649cdc52d21ed3aba9b1a8023167216.jpg              2  OK
# Extracting  raw/images/0649e9702d8ae1a4106019f99cd36c2c.jpg              2  OK
# Extracting  raw/images/064cf2f500fc02a9bb0994db5a4827f8.jpg              2  OK
# Extracting  raw/images/0674d476d09ef77bd17da5c6c8d63c9b.jpg              2  OK
# Extracting  raw/images/06754267fe8148bc98a42e8ad52897b0.jpg              2  OK
# Extracting  raw/images/067570b3ec1d7fd1e8f1e7aa32d08b1d.jpg              2  OK
# Extracting  raw/images/067ceed0e568f0fec9e420fa2e3a7e56.jpg              2  OK
# Extracting  raw/images/068a3937b668bd480e34ae03e85f9b4e.jpg              2  OK
# Extracting  raw/images/068b3c2a02ee7cbc3e0b293664985a7b.jpg              2  OK
# Extracting  raw/images/0690039523bc91fcac0a31c0095461a3.jpg              2  OK
# Extracting  raw/images/06a1a000995ca2053a85a5a66847cc25.jpg              2  OK
# Extracting  raw/images/06a6affb77ee9f4fa3ec70019b67cec4.jpg              2  OK
# Extracting  raw/images/06ac93e0f4c4e87f69a3e2634c957cc7.jpg              2  OK
# Extracting  raw/images/06ba063a24fa14903cb65a3bffbc77e2.jpg              2  OK
# Extracting  raw/images/06c1093c876974ad97dc0e081170de46.jpg              2  OK
# Extracting  raw/images/06c93d5db3adfc28ea345e54a40c76c6.jpg              2  OK
# Extracting  raw/images/06cda4e0259992c410d7b6bcb004ca71.jpg              2  OK
# Extracting  raw/images/06cea8cabe935139bf37fa9ce00f42d7.jpg              2  OK
# Extracting  raw/images/06d23af1ed25077436a36de488214829.jpg              2  OK
# Extracting  raw/images/06de51754ba7d8baf62fae440123890d.jpg              2  OK
# Extracting  raw/images/06defebba44ee781aef61bb3ef948884.jpg              2  OK
# Extracting  raw/images/06e02bbeae92d13697e33596ec3c72a3.jpg              2  OK
# Extracting  raw/images/06e05240c23c01599816adf43899593b.jpg              2  OK
# Extracting  raw/images/06f4fc97cab225179b9d8950785cc89e.jpg              2  OK
# Extracting  raw/images/07084236707e9f2eafb7a531207d7dc0.jpg              2  OK
# Extracting  raw/images/070ff13c834ea8c4c3624ef734f84f5c.jpg              2  OK
# Extracting  raw/images/07210b2e5f113cf9dcf8ed5d5f3a4b6a.jpg              2  OK
# Extracting  raw/images/07217b23cec3bd4ef0538c91a810904a.jpg              2  OK
# Extracting  raw/images/0723e0a0994832e6a34c4c348a3db3d4.jpg              2  OK
# Extracting  raw/images/0727bfc0b63da0682930ac58a986aa72.jpg              2  OK
# Extracting  raw/images/072a68272a69307fd73c63391e3b62c2.jpg              2  OK
# Extracting  raw/images/07381c666a8a9b3a0d6c1ce72cd47cac.jpg              2  OK
# Extracting  raw/images/0740268ccc17584dc6cdee23b0043f4f.jpg              2  OK
# Extracting  raw/images/074f4a648b814f66ad0ebf1dc1a7cc58.jpg              2  OK
# Extracting  raw/images/075542875adc23a090bd8e8de4bb5435.jpg              2  OK
# Extracting  raw/images/075619baa6e9c22e4955dd5c97f3b97c.jpg              2  OK
# Extracting  raw/images/076ab7c5a593681d645bf26f83801b1f.jpg              2  OK
# Extracting  raw/images/07751c94d8a08186a13396a493207c23.jpg              2  OK
# Extracting  raw/images/0778b70a770bb3135bd2525028edf536.jpg              2  OK
# Extracting  raw/images/077a24a605382ad2623a69fa9c58414c.jpg              2  OK
# Extracting  raw/images/0786f59294df93c29c945e0f370825ca.jpg              2  OK
# Extracting  raw/images/07892c8017628cdd1b109190e3b31f1e.jpg              2  OK
# Extracting  raw/images/07971f493b5c5c96a226a1679fe5898c.jpg              2  OK
# Extracting  raw/images/079c450d12649c8c9563e8c7f7e7193f.jpg              2  OK
# Extracting  raw/images/07ab12aabf47cf31fc4ba7cc9b599ac0.jpg              2  OK
# Extracting  raw/images/07ac825d3a69c02ba4e66f93a1d24229.jpg              2  OK
# Extracting  raw/images/07bd25c89cb2f44446c3fb757c65d993.jpg              2  OK
# Extracting  raw/images/07c43fbcec360c0629566c213990982b.jpg              2  OK
# Extracting  raw/images/07c5d32680b3b91a229674079a5336ed.jpg              2  OK
# Extracting  raw/images/07deac713cf66ba6d24b20b782f74aff.jpg              2  OK
# Extracting  raw/images/08019c477a11b63c1a21b1bd6a401609.jpg              2  OK
# Extracting  raw/images/080211de764dafaf1b48e46492b49bac.jpg              2  OK
# Extracting  raw/images/08069a1b5ca44dbad916ad57a119b2c8.jpg              2  OK
# Extracting  raw/images/080b2bf6f02ad0ee43e9642ee99653d6.jpg              2  OK
# Extracting  raw/images/080d0a59aa580cb39ad129526485c419.jpg              2  OK
# Extracting  raw/images/080f3be394c49dfe764e15bafeba14b0.jpg              2  OK
# Extracting  raw/images/0810b0c5aa23bf0da4b282c5bf2c100c.jpg              2  OK
# Extracting  raw/images/08142cfc052cd0e58dbdfd25b9c76ea9.jpg              2  OK
# Extracting  raw/images/081ac79299055d204de2eac4387f5cce.jpg              2  OK
# Extracting  raw/images/081e7bb3832ec5bb25276db161a96274.jpg              2  OK
# Extracting  raw/images/082524eb5f8f1336a6af238cfcf0bce8.jpg              2  OK
# Extracting  raw/images/082d4ae6a26ba11efb21b80fc7d2d55e.jpg              2  OK
# Extracting  raw/images/08375747bbf8a35b2fa9d644ffd472c0.jpg              2  OK
# Extracting  raw/images/083cd9de9281478b5664fbf1e95a972b.jpg              2  OK
# Extracting  raw/images/0847692def1b8ed123e0f697a1684555.jpg              2  OK
# Extracting  raw/images/0855c8dff9bf5f4a2714b724ee701591.jpg              2  OK
# Extracting  raw/images/0864a1f58713463aa61353819526481b.jpg              2  OK
# Extracting  raw/images/0864b74e98e54d84f8ded9bb4803eb22.jpg              2  OK
# Extracting  raw/images/087eab59bcd4ecfbadbb77d385c855be.jpg              2  OK
# Extracting  raw/images/08900ab02e2f8b234dfc1adfc9130d5a.jpg              2  OK
# Extracting  raw/images/089651a79bf162f40e011b47457e77df.jpg              2  OK
# Extracting  raw/images/089c3b993cd7cb2b78321b3eaa353f49.jpg              2  OK
# Extracting  raw/images/08a9e0a613c5c8bd17db9f5289c90f75.jpg              2  OK
# Extracting  raw/images/08b547777bd89b4ac2a69ad46d8687bf.jpg              2  OK
# Extracting  raw/images/08bb5a25ba46f6e4f89986028f9cacf9.jpg              2  OK
# Extracting  raw/images/08bc322a086845fdff2f05356b8c90b2.jpg              2  OK
# Extracting  raw/images/08be28ab3a97154503c724d094a91e51.jpg              3  OK
# Extracting  raw/images/08c0cd48330f8426bdfdda9ef5f1dccb.jpg              3  OK
# Extracting  raw/images/08c362323b428a71eb83aecfca231473.jpg              3  OK
# Extracting  raw/images/08c51b35f0ea6c8ca12e00fa5ccc7b3e.jpg              3  OK
# Extracting  raw/images/08ccb70fae5611a562f8bce98bd95631.jpg              3  OK
# Extracting  raw/images/08cf15656b288fc32421d54bb3e35e82.jpg              3  OK
# Extracting  raw/images/08e1ae6d129b026986f733eac74e0b83.jpg              3  OK
# Extracting  raw/images/08e8b68c7aae150314d5749e24f0711e.jpg              3  OK
# Extracting  raw/images/08eac04d0d1696c89644c4e33869ee3c.jpg              3  OK
# Extracting  raw/images/08ebd9b06edfaa1da62155097071419d.jpg              3  OK
# Extracting  raw/images/08fc4f0f3315eff2f7b0dd0e62d9c4a6.jpg              3  OK
# Extracting  raw/images/08ff821382070d96d7cb1b74f921459e.jpg              3  OK
# Extracting  raw/images/09051f09aeed197cd12a4a8ebfceb3d0.jpg              3  OK
# Extracting  raw/images/0911fcb30398deb4584d6f47bd5b46ef.jpg              3  OK
# Extracting  raw/images/091c16cfb96f3766ae9ac32f80e5e8b1.jpg              3  OK
# Extracting  raw/images/0923798adb1bd72fdc0cbda0d81e8031.jpg              3  OK
# Extracting  raw/images/09294b3485395f7277a59eeb2cab9be7.jpg              3  OK
# Extracting  raw/images/092ddcd4b0d09cf5dd2522ebfc7de36c.jpg              3  OK
# Extracting  raw/images/09301edd0964972b13e2b7f4b09b65a9.jpg              3  OK
# Extracting  raw/images/0933cdfb4e657eb96bae48f7a5eabe16.jpg              3  OK
# Extracting  raw/images/0949e28602a56a039abcdf6d2d3c366c.jpg              3  OK
# Extracting  raw/images/094ccb73c49523ad36b4cc7bd01cb410.jpg              3  OK
# Extracting  raw/images/094fdf4fbf2081a81d1d3d055b4f8800.jpg              3  OK
# Extracting  raw/images/095146fd9586bafcee6f149eb9127750.jpg              3  OK
# Extracting  raw/images/0955f806e5e9fd396eedf9f831f100d1.jpg              3  OK
# Extracting  raw/images/0960bc8b8c2d9bfeb50e316732aebb61.jpg              3  OK
# Extracting  raw/images/0961553d09c9592efba935ae35d70306.jpg              3  OK
# Extracting  raw/images/09644ff5f887fc2caf165f0814b55cda.jpg              3  OK
# Extracting  raw/images/096d03848e8c710dbe821bb3641997b3.jpg              3  OK
# Extracting  raw/images/0972d5c92e47250955946420aa714913.jpg              3  OK
# Extracting  raw/images/097f48b22802f8b5f1a71a2a23d14dcf.jpg              3  OK
# Extracting  raw/images/09810ade08e534bd43aeb3a3ca1ea9d1.jpg              3  OK
# Extracting  raw/images/0988c92ae58705a296ab1877b023c768.jpg              3  OK
# Extracting  raw/images/098b43bae190eca94ea39ee59e4cc068.jpg              3  OK
# Extracting  raw/images/0993d7ddddb267d09268b71868821b5f.jpg              3  OK
# Extracting  raw/images/099b00ffc1a6673e00edfee27f76d0ff.jpg              3  OK
# Extracting  raw/images/099eca4d4efdeac0ec6b4745ef5a93dc.jpg              3  OK
# Extracting  raw/images/09a035ff29f30688bb01ea001c50aa47.jpg              3  OK
# Extracting  raw/images/09a71ea11f4d23d5a48d7dc1079bd8f3.jpg              3  OK
# Extracting  raw/images/09a77c30ecbb3c27a3d5c739cf6d9256.jpg              3  OK
# Extracting  raw/images/09ab9328b20a1f0ba24c388064792a34.jpg              3  OK
# Extracting  raw/images/09af3758b0d4ba4196f63007c701e987.jpg              3  OK
# Extracting  raw/images/09b8258a95f87d0c9cd8356153a63bbf.jpg              3  OK
# Extracting  raw/images/09b96fc50f5cc813f35d6a1bef95ff2c.jpg              3  OK
# Extracting  raw/images/09ba3566bd835c9712add11af8755221.jpg              3  OK
# Extracting  raw/images/09ba58c24e6cda731ca6f9b656ec88ea.jpg              3  OK
# Extracting  raw/images/09d3d3eb69c3804a2a01567d7b09deef.jpg              3  OK
# Extracting  raw/images/09d51ae77d98c3f836fa3fc212e67032.jpg              3  OK
# Extracting  raw/images/09deb19775c2d78ec0547eb200427e96.jpg              3  OK
# Extracting  raw/images/09f5778abb55dd38a2a2eb2803ebb05b.jpg              3  OK
# Extracting  raw/images/09f61df2adae3dcd95a4e05286b1af9d.jpg              3  OK
# Extracting  raw/images/09fafcca79169a01657dbf9c05fae61b.jpg              3  OK
# Extracting  raw/images/0a060c50f1dcd53eb262f96501a8ac95.jpg              3  OK
# Extracting  raw/images/0a1ea4614a9df912eeb8d1b40bffee74.jpg              3  OK
# Extracting  raw/images/0a2395009a83ce904b3e707a98d78334.jpg              3  OK
# Extracting  raw/images/0a23d1c51c12eff5ae6f6c47a39fe7f1.jpg              3  OK
# Extracting  raw/images/0a281913e0b0d36b1484348ec6014544.jpg              3  OK
# Extracting  raw/images/0a2bc0dc2371794509f4b776aff0dd88.jpg              3  OK
# Extracting  raw/images/0a31a59eeadbcbeee9949dd74af7081b.jpg              3  OK
# Extracting  raw/images/0a39d1bcea61bb0a20eba63f76c66eb3.jpg              3  OK
# Extracting  raw/images/0a490958aac3c79bb815a0f1f6825284.jpg              3  OK
# Extracting  raw/images/0a4e0e88a05abd96670c8c0c3a67fc73.jpg              3  OK
# Extracting  raw/images/0a4f38c94dd63cd8e5b9209dc9892146.jpg              3  OK
# Extracting  raw/images/0a584ddb325ed1ab4083d341280caaa8.jpg              3  OK
# Extracting  raw/images/0a6e61d19443e62f7fffe643e327954e.jpg              3  OK
# Extracting  raw/images/0a72289b0b455d083ed606f24504d74c.jpg              3  OK
# Extracting  raw/images/0a7bda3ef30b632b39a18a2c34bcc872.jpg              3  OK
# Extracting  raw/images/0a82e45ed11fb9ef1620a0b40cd9f6d8.jpg              3  OK
# Extracting  raw/images/0a9c0e283b2068a74e40ddd25251a0c8.jpg              3  OK
# Extracting  raw/images/0a9f629a08cfa8616038069ad3b3a78b.jpg              3  OK
# Extracting  raw/images/0ab45975869f5f6e5a1428f8d00c5987.jpg              3  OK
# Extracting  raw/images/0ab5f928355f3480a1922dbfde1521f0.jpg              3  OK
# Extracting  raw/images/0ab67254ad39838a049e8b1167137145.jpg              3  OK
# Extracting  raw/images/0ab800b68e72698028b4b3d8c7e7a212.jpg              3  OK
# Extracting  raw/images/0ab8f4c4a3de27c56737833a7a27346c.jpg              3  OK
# Extracting  raw/images/0ac01d1803865c7ce0f88f9775de11a8.jpg              3  OK
# Extracting  raw/images/0acc677275be3b47e1fe32540586619e.jpg              3  OK
# Extracting  raw/images/0acc9a6d945cd31a1ea4cff5dd3ce95b.jpg              3  OK
# Extracting  raw/images/0accacf1a65fa522ce87ecf98b00a05b.jpg              3  OK
# Extracting  raw/images/0ad9db7f888140d987adedd258a9130e.jpg              3  OK
# Extracting  raw/images/0adda1adc06e0b8d857a62e80649b902.jpg              3  OK
# Extracting  raw/images/0ae5acf51c8e92a5e073e3faead1ae33.jpg              3  OK
# Extracting  raw/images/0ae7702104c8b5936655ae8035636772.jpg              3  OK
# Extracting  raw/images/0aed9ff03dddc1996976caa5f68e65f4.jpg              3  OK
# Extracting  raw/images/0af15d2e99c4058ced1d9020f29d926c.jpg              3  OK
# Extracting  raw/images/0af9f710ae913dad1bbea7acfcb9cb5c.jpg              3  OK
# Extracting  raw/images/0b031e5daf99981b7d907b5ab76b49be.jpg              3  OK
# Extracting  raw/images/0b044733efca9f84ee99018e1e9e81cb.jpg              3  OK
# Extracting  raw/images/0b15e50856ce08c9771949ce2d6538b1.jpg              3  OK
# Extracting  raw/images/0b18e00ab6d363022e094b618adb40af.jpg              3  OK
# Extracting  raw/images/0b1bab05fe5811f615a96423526bcecb.jpg              3  OK
# Extracting  raw/images/0b25dc9a210bed276dab3a6f1d6628e5.jpg              3  OK
# Extracting  raw/images/0b30c58b935ec6cbe6b5c8531ff4d6f6.jpg              3  OK
# Extracting  raw/images/0b3551e0ddabe2f2ac51c43c68cd3754.jpg              3  OK
# Extracting  raw/images/0b3b0fa251ab9acb5b8bcb5f4fa56772.jpg              3  OK
# Extracting  raw/images/0b4d23930f2ac9af6019bd0d985e1f2c.jpg              3  OK
# Extracting  raw/images/0b4d4c705193c55b0de61c77a782c1c3.jpg              3  OK
# Extracting  raw/images/0b4e39c1e1cd3780a8e74403b50aadae.jpg              3  OK
# Extracting  raw/images/0b4f82479ad2e735c2d031548f460367.jpg              3  OK
# Extracting  raw/images/0b504fb91a9b403dd4eb1341cbb98dd4.jpg              4  OK
# Extracting  raw/images/0b55874525b539ac5d2e93c0d2e06957.jpg              4  OK
# Extracting  raw/images/0b5ae0fdef800059e0511c6ba2168ade.jpg              4  OK
# Extracting  raw/images/0b5b0155f6446aaf834cb086a155228c.jpg              4  OK
# Extracting  raw/images/0b76a18ce1f09ee4a6fbc11663a2d07f.jpg              4  OK
# Extracting  raw/images/0b7a13e053b7da69a6d316f0f686ea30.jpg              4  OK
# Extracting  raw/images/0b7a8579f30ce5a8e2680bd34559955f.jpg              4  OK
# Extracting  raw/images/0b7b1672c6bed5a7e2f1a5618787c6f0.jpg              4  OK
# Extracting  raw/images/0b7d2ce04a23d64736152811a1ff250d.jpg              4  OK
# Extracting  raw/images/0b7f698c3b61b32b6b11d4aa1020b905.jpg              4  OK
# Extracting  raw/images/0b8acebd823fee244034eff07dc37623.jpg              4  OK
# Extracting  raw/images/0b8bb405ed73ceceedf7b450a1966b39.jpg              4  OK
# Extracting  raw/images/0b993acc38a4103db91c85e2f03c43c0.jpg              4  OK
# Extracting  raw/images/0b9d6270966b91f5e1e25a607e9acb77.jpg              4  OK
# Extracting  raw/images/0b9e328782e05c2f65d81ddd006d7216.jpg              4  OK
# Extracting  raw/images/0ba2a22e1f8aa653476ce5f957a85310.jpg              4  OK
# Extracting  raw/images/0ba95f0c5d5badea292d562a4b2efcd4.jpg              4  OK
# Extracting  raw/images/0bc4467f2ceacceecb211c73c6f33d08.jpg              4  OK
# Extracting  raw/images/0bc6765b04a37252bfab4663e1a00b19.jpg              4  OK
# Extracting  raw/images/0bc9a9833b2626aac2aca5a98ea3a986.jpg              4  OK
# Extracting  raw/images/0bd667bfa8c0213c5d7e8d56424029f6.jpg              4  OK
# Extracting  raw/images/0bd7e6fb8d2002b30f524213b88bd5c8.jpg              4  OK
# Extracting  raw/images/0bd806a66f1d4e4302b354c34baca077.jpg              4  OK
# Extracting  raw/images/0bd8fb4dc195a2b098c8362ab9bbd85a.jpg              4  OK
# Extracting  raw/images/0bd97eb285fcedd86932513f674b162b.jpg              4  OK
# Extracting  raw/images/0be41203ef4550a7e430cfc21a0aadb0.jpg              4  OK
# Extracting  raw/images/0c002beffd10374f52471b54aa569295.jpg              4  OK
# Extracting  raw/images/0c0470911e57a5ed7de67279bd7140a0.jpg              4  OK
# Extracting  raw/images/0c0a14739e277aefc9762d25bb06c175.jpg              4  OK
# Extracting  raw/images/0c22283943d6195ca3cb12358a3c41f7.jpg              4  OK
# Extracting  raw/images/0c28810946f06badf950b57a3789d6c2.jpg              4  OK
# Extracting  raw/images/0c339f674a8bf71378419fc434bab823.jpg              4  OK
# Extracting  raw/images/0c368cabaf2d03fa161610701da7f3ae.jpg              4  OK
# Extracting  raw/images/0c36c2e1f46f11c5d5bd490ec73b4632.jpg              4  OK
# Extracting  raw/images/0c42ceaf002703bcd43ce26419db068a.jpg              4  OK
# Extracting  raw/images/0c4619417da97d1bc78cf5d5c4f095db.jpg              4  OK
# Extracting  raw/images/0c4abc2dccfa07888fce220461eb83fb.jpg              4  OK
# Extracting  raw/images/0c51c85b3ad0b2122afa951e1d44277d.jpg              4  OK
# Extracting  raw/images/0c60aeb768a125999b9b69179f10a479.jpg              4  OK
# Extracting  raw/images/0c635a57a4e2337ed8fa32870016ac05.jpg              4  OK
# Extracting  raw/images/0c66dff7ad03b0b4c96adce0ecdda54c.jpg              4  OK
# Extracting  raw/images/0c70aa158825293871d69568ed9d5964.jpg              4  OK
# Extracting  raw/images/0c74e04cdffb72672ae1e33aaea01fe0.jpg              4  OK
# Extracting  raw/images/0c7530807e596cf61181f433b0a1dcbc.jpg              4  OK
# Extracting  raw/images/0c75c5a189d01d80c275e47be1fba699.jpg              4  OK
# Extracting  raw/images/0c8e4819d770c07f47324bdd5870eefc.jpg              4  OK
# Extracting  raw/images/0c915ff608330cb8d4a54382da9d6ae9.jpg              4  OK
# Extracting  raw/images/0c91a440ef40a7ff17cf187147222efb.jpg              4  OK
# Extracting  raw/images/0c92987b3e7cbb325e67b35774be2b45.jpg              4  OK
# Extracting  raw/images/0c94ad4fe7827a372539481433616372.jpg              4  OK
# Extracting  raw/images/0c9e311b497e900474cf35e2a8fc0add.jpg              4  OK
# Extracting  raw/images/0ca5718f791e6057faf260086330f9a9.jpg              4  OK
# Extracting  raw/images/0cb37e69db81991df8cd6b20a338e031.jpg              4  OK
# Extracting  raw/images/0cc40f63d93128dbd3f08e2f709530fb.jpg              4  OK
# Extracting  raw/images/0cd9114955c896f7c445343eb2a62996.jpg              4  OK
# Extracting  raw/images/0ce004ab49dd1590d3b7b3248cb4b042.jpg              4  OK
# Extracting  raw/images/0ce28af03ec6ca48cf3e9abf338150de.jpg              4  OK
# Extracting  raw/images/0ce48da260e9805f24ecad0e8c4a7619.jpg              4  OK
# Extracting  raw/images/0cea01b93119a3e2e78f83841ef7e7c9.jpg              4  OK
# Extracting  raw/images/0cf652a0de06363dd078b39b5e46403f.jpg              4  OK
# Extracting  raw/images/0cfadfcfa6279ee6623d3bcb8d189cfe.jpg              4  OK
# Extracting  raw/images/0d01179e058c1f6706e04c7a2d90a7f8.jpg              4  OK
# Extracting  raw/images/0d018b509a61b4c32ae9abe5b5bbe677.jpg              4  OK
# Extracting  raw/images/0d12d4951d410ff0832a66fd58cd127d.jpg              4  OK
# Extracting  raw/images/0d16e8135bab71d0aac0069277d1db89.jpg              4  OK
# Extracting  raw/images/0d1b0324a9f32929b59bcdda70ccc2b0.jpg              4  OK
# Extracting  raw/images/0d200a6761b3ebd25b290fc3b4008bd3.jpg              4  OK
# Extracting  raw/images/0d28ba5b2d2c050dc58538950f159245.jpg              4  OK
# Extracting  raw/images/0d34f3e7baddabff5c8fe76f4798805e.jpg              4  OK
# Extracting  raw/images/0d381ce87d91f7173d368191ca9547f2.jpg              4  OK
# Extracting  raw/images/0d388299cdf765ab44b935b1d1fd512b.jpg              4  OK
# Extracting  raw/images/0d43e79424b7f56577a22d8d42045ac7.jpg              4  OK
# Extracting  raw/images/0d45bfb08eb484cf4413359d8eab651b.jpg              4  OK
# Extracting  raw/images/0d494d23f9c321a8757e06a702f16fff.jpg              4  OK
# Extracting  raw/images/0d4a6a6cb1209a83efbbb97c37c88dea.jpg              4  OK
# Extracting  raw/images/0d4d6645713bff7813e73cd12a40a40e.jpg              4  OK
# Extracting  raw/images/0d9279f06a6e908ae59f50a449f63fde.jpg              4  OK
# Extracting  raw/images/0da0275c48991ba484071001dcb62fd8.jpg              4  OK
# Extracting  raw/images/0da4f9d8e3a8e55630df17e0c55aeb0e.jpg              4  OK
# Extracting  raw/images/0da8dda3b6b96febb86f39134a0780b6.jpg              4  OK
# Extracting  raw/images/0dacd86b01d87b56e56415cc51a182ed.jpg              4  OK
# Extracting  raw/images/0dae04540733dad54d1eabdbff2c7425.jpg              4  OK
# Extracting  raw/images/0db0142730587b7151b909d52f79d0bc.jpg              4  OK
# Extracting  raw/images/0dc0d15ccecaf6da95008fdc6c05fb6b.jpg              4  OK
# Extracting  raw/images/0dc119aa65a3064a659d3d763b82c717.jpg              4  OK
# Extracting  raw/images/0dc464bf9aaa382ce31edda2899099e7.jpg              4  OK
# Extracting  raw/images/0ddb6b1201c80f88139ef0c7da78d3be.jpg              4  OK
# Extracting  raw/images/0dde599c312150ddbc41ecc865b3b047.jpg              4  OK
# Extracting  raw/images/0de90c31de9923835a675f5b8fad9bfe.jpg              4  OK
# Extracting  raw/images/0defa55f906743389b376a73715537af.jpg              4  OK
# Extracting  raw/images/0df63e54461e0043573d7aa086bfbed4.jpg              4  OK
# Extracting  raw/images/0dfdd76487ac9ec3f08fe56f495e99d5.jpg              4  OK
# Extracting  raw/images/0dfe52c707e21f2ef97e7a406113cd06.jpg              4  OK
# Extracting  raw/images/0e005f51d165c7b617da6b9c26aa0510.jpg              4  OK
# Extracting  raw/images/0e04b306f2471979e824c6b4b34763b0.jpg              4  OK
# Extracting  raw/images/0e1770e4a8a6a69566b96b3ec5fc1212.jpg              4  OK
# Extracting  raw/images/0e19c5bcd1902931b5f8154708041d02.jpg              4  OK
# Extracting  raw/images/0e1e1a5400a2983e8679d9042ae8d5d8.jpg              5  OK
# Extracting  raw/images/0e2324da2900dcdf1ec81b35aca6b8ae.jpg              5  OK
# Extracting  raw/images/0e2b154ce23760519ad2a5cc550f2c3b.jpg              5  OK
# Extracting  raw/images/0e2feddfa6d13e4c3d409d8a6df4a59a.jpg              5  OK
# Extracting  raw/images/0e30c2a3c1c661e4b7e3c0cdc58915f4.jpg              5  OK
# Extracting  raw/images/0e30e713f2741ce3281d6409592a62e8.jpg              5  OK
# Extracting  raw/images/0e3bb77f97de93bbe935466f0befe889.jpg              5  OK
# Extracting  raw/images/0e40420d5a5460542ea8dc87bc56b2e6.jpg              5  OK
# Extracting  raw/images/0e47a143c0f524e0d16a27f29a83102c.jpg              5  OK
# Extracting  raw/images/0e506ddbe9e654f92c6cd97bf9899ba6.jpg              5  OK
# Extracting  raw/images/0e53eca9a109268719bd710a826bf603.jpg              5  OK
# Extracting  raw/images/0e5df17af369fbf99ba6aaaaeb3ff189.jpg              5  OK
# Extracting  raw/images/0e732b60caf8bff1310b395b059a2365.jpg              5  OK
# Extracting  raw/images/0e775609f58653980b0e31e357e63d2f.jpg              5  OK
# Extracting  raw/images/0e7d8f86eb92a19b9cfd898e2103c6b6.jpg              5  OK
# Extracting  raw/images/0e82ec3eb9798e3166be773f8942df40.jpg              5  OK
# Extracting  raw/images/0e83c9b5dd9ea8b038dd39bc6598e0b6.jpg              5  OK
# Extracting  raw/images/0e843a1aa933951a69d887aafafbb94a.jpg              5  OK
# Extracting  raw/images/0e974b578b8767f545a4a59994e02735.jpg              5  OK
# Extracting  raw/images/0ea2c48fd914b91ce0c1b9b07c76590e.jpg              5  OK
# Extracting  raw/images/0ea2c60055df54d117720f777a89fcb4.jpg              5  OK
# Extracting  raw/images/0ea303c34d426b41aa342ed6acd6108e.jpg              5  OK
# Extracting  raw/images/0eaef6e657f341bb0167cc893dfe8fc6.jpg              5  OK
# Extracting  raw/images/0eb207a4fe390364bdf229da5c3a97dd.jpg              5  OK
# Extracting  raw/images/0eb4d68fcd12a4e5be6fb85255b86132.jpg              5  OK
# Extracting  raw/images/0ebcfb42ea1c413ab47febe17c48d7ad.jpg              5  OK
# Extracting  raw/images/0ec19b78e71f1f04e1d1f06c16fa4094.jpg              5  OK
# Extracting  raw/images/0ec72fbac7662b8e0e89b29663324128.jpg              5  OK
# Extracting  raw/images/0ec9656d431a711a03afd1c601d0fce0.jpg              5  OK
# Extracting  raw/images/0ed0d1a503c19b44e29f0ba8d5ee7b0e.jpg              5  OK
# Extracting  raw/images/0edd4a0e72c4804b4234db4d62b1290a.jpg              5  OK
# Extracting  raw/images/0edf5356c2b50a545d9f40a8cbf43e82.jpg              5  OK
# Extracting  raw/images/0ee0fce02fc8739755459f00e6e7b66c.jpg              5  OK
# Extracting  raw/images/0ee43fc7ba28742044104c23e7abafd7.jpg              5  OK
# Extracting  raw/images/0eed32ba52881e1430fa72aea7a6f4cc.jpg              5  OK
# Extracting  raw/images/0ef61642a4f8763b7b455ed3812d63b4.jpg              5  OK
# Extracting  raw/images/0effc8108d77af7ed5872cd016ce7efa.jpg              5  OK
# Extracting  raw/images/0f18d0b05511187a731efc8a65632113.jpg              5  OK
# Extracting  raw/images/0f1c12d264738de75f12714d6da6be5d.jpg              5  OK
# Extracting  raw/images/0f1ec4e8822d155e3b5af15cd46be07a.jpg              5  OK
# Extracting  raw/images/0f24e33b0120b1cc8f086a6ba5301da9.jpg              5  OK
# Extracting  raw/images/0f2509bd345f183f8033346eeaeb3aca.jpg              5  OK
# Extracting  raw/images/0f287570892eef045426aec98343bb3f.jpg              5  OK
# Extracting  raw/images/0f3bd930bda420e112c2477ebc92b24e.jpg              5  OK
# Extracting  raw/images/0f4b44945ac3d3073851588f9049a800.jpg              5  OK
# Extracting  raw/images/0f50740044859c25377cd124d556461a.jpg              5  OK
# Extracting  raw/images/0f55de86c37024e3eb5f1f9ca187bb87.jpg              5  OK
# Extracting  raw/images/0f5a89fb2cf9aa789268b6c5783372bf.jpg              5  OK
# Extracting  raw/images/0f621d5491939f6febd38c2be9f6c887.jpg              5  OK
# Extracting  raw/images/0f69f4b3c6e1bd19b3498f62b05e5726.jpg              5  OK
# Extracting  raw/images/0f6a21dde26e0f606db0f1a4593a0377.jpg              5  OK
# Extracting  raw/images/0f70cb95c7fc1f6119b55f3be27fdd95.jpg              5  OK
# Extracting  raw/images/0f79fe879fa3fa646f149de86b1642e9.jpg              5  OK
# Extracting  raw/images/0f87afa3e367f6bfaec029dea3f6d528.jpg              5  OK
# Extracting  raw/images/0f89b662bdeb74f42b70c6a4e28f62e4.jpg              5  OK
# Extracting  raw/images/0f8c35a29c307f35b938ab2147c62602.jpg              5  OK
# Extracting  raw/images/0f91ec1533b845b13089f8cf4e0a36f7.jpg              5  OK
# Extracting  raw/images/0f9afc579438ec12fe753e88bb40e2d7.jpg              5  OK
# Extracting  raw/images/0f9c03be14d8e2d26ee0926cc524ef1b.jpg              5  OK
# Extracting  raw/images/0f9cb3fa3b9f1a590997d7ca72313505.jpg              5  OK
# Extracting  raw/images/0fa5e270b60ec2a7353664c81d651bcc.jpg              5  OK
# Extracting  raw/images/0fa7fa84aff23ea2c29ba5793fc371a4.jpg              5  OK
# Extracting  raw/images/0fb9ec4a46ba5e1d9fefadecc3dc0a6b.jpg              5  OK
# Extracting  raw/images/0fbfe80c0949bcc0f35f4c7484a83a52.jpg              5  OK
# Extracting  raw/images/0fc6c456b47ab87cb01b3705a617fee2.jpg              5  OK
# Extracting  raw/images/0fd9a68940ec837f0e43ac3ad72b089d.jpg              5  OK
# Extracting  raw/images/0fda747d6e10b51bd50151706eef9bbe.jpg              5  OK
# Extracting  raw/images/0fde3b86fd64612db20cf1c10d7c5cb9.jpg              5  OK
# Extracting  raw/images/0ffc2cba58a51ff379d536a6ec8e7664.jpg              5  OK
# Extracting  raw/images/0fffb8604ccda9f6602d4d7aaba8cea8.jpg              5  OK
# Extracting  raw/images/1007c616eb8836139e4185503909e160.jpg              5  OK
# Extracting  raw/images/100bd4c75d6f9210891a4dde826ec7dd.jpg              5  OK
# Extracting  raw/images/100f1f088de22d9d7c4c7d1fdb8e7685.jpg              5  OK
# Extracting  raw/images/10124309182b27fbfa68541592c3557d.jpg              5  OK
# ...
# Extracting  raw/images/fb23e0a8865099d9f1ef2e8e297fdecc.jpg             97  OK
# Extracting  raw/images/fb25daa6924b3d6998b73246539754ed.jpg             97  OK
# Extracting  raw/images/fb2694959ec5f860e5e0def8b09b5c54.jpg             98  OK
# Extracting  raw/images/fb2fb9aa238182ad79651903a8ba12d4.jpg             98  OK
# Extracting  raw/images/fe20ce76e5e5dad810322af9b683f471.jpg             99  OK
# Extracting  raw/images/fe250f3ebe247fca8c2bda6cbba34f93.jpg             99  OK
# Extracting  raw/images/fe26a0704daab304d4da7509511e1845.jpg             99  OK
# Extracting  raw/images/fe26f29117042c3cc41b4eb096197cc4.jpg             99  OK
# Extracting  raw/images/fe2979002129e876d31957d970029c78.jpg             99  OK
# Extracting  raw/images/fe299bcc5e802b3f6f0e5f6ac3ec019e.jpg             99  OK
# Extracting  raw/images/fe35f3b78b83d90e8a6a4f5cbe034848.jpg             99  OK
# Extracting  raw/images/fe3699b28f507c2006dc3120e00b8094.jpg             99  OK
# Extracting  raw/images/fe38651ecebd29f0886547e8687b3088.jpg             99  OK
# Extracting  raw/images/fe38bdc6396f1d2c5852f0783bf4fef6.jpg             99  OK
# Extracting  raw/images/fe4a6e94b1ca1fb42f42b8fc6c81ffa8.jpg             99  OK
# Extracting  raw/images/fe4aa65fe506e2f73e9fdd096166c5c7.jpg             99  OK
# Extracting  raw/images/fe4bf9c5c884f0cb4c04c500e110d2ee.jpg             99  OK
# Extracting  raw/images/fe4dac6d2981f98fc0da2ca75666cb9f.jpg             99  OK
# Extracting  raw/images/fe64d8ea6499433cc6a632995782e674.jpg             99  OK
# Extracting  raw/images/fe683b24119d9a04ca94acfd9559efb2.jpg             99  OK
# Extracting  raw/images/fe7e33ca84717759a621e301bfeaa999.jpg             99  OK
# Extracting  raw/images/fe8c1af187242788768dd3e4eae4751b.jpg             99  OK
# Extracting  raw/images/fe912a1efbb508190a9fa072eeb3307c.jpg             99  OK
# Extracting  raw/images/fe96e7ed9ef749b69d0b74096011cf75.jpg             99  OK
# Extracting  raw/images/fe9a62ef6b2457b4b5b72896266a056c.jpg             99  OK
# Extracting  raw/images/fea9314719ab39785cb3bf2427fe27e5.jpg             99  OK
# Extracting  raw/images/feabdc81fdd10360da5958d9765198ed.jpg             99  OK
# Extracting  raw/images/feb74102bbdd3530eb6fa20bfbf51a76.jpg             99  OK
# Extracting  raw/images/feb8e5c27d6f096ed0272caaa428f679.jpg             99  OK
# Extracting  raw/images/feba2ddb4402496fdc646d2318aba9ce.jpg             99  OK
# Extracting  raw/images/febca4c995d13787f0c00cc213f1093d.jpg             99  OK
# Extracting  raw/images/fec27f3f16b48d29c919b06888c79305.jpg             99  OK
# Extracting  raw/images/fec8f786614ddd87b1c6b25c1a606b19.jpg             99  OK
# Extracting  raw/images/fec90b848c9b6c4bcc1ec562597c55d8.jpg             99  OK
# Extracting  raw/images/fecd82ed9ca7aba9bc021007728310ae.jpg             99  OK
# Extracting  raw/images/fed5e6d093f3ca16365be04571bfbebc.jpg             99  OK
# Extracting  raw/images/fed5ffbb860406d1c12aaf761ea80da4.jpg             99  OK
# Extracting  raw/images/fee014432f887553e9efe81196e8d40a.jpg             99  OK
# Extracting  raw/images/fee3d029444749798019d031d92aea9f.jpg             99  OK
# Extracting  raw/images/fee4a81f80654d1c66e984a0d018dd0d.jpg             99  OK
# Extracting  raw/images/ff9412338660096616a85090e09f0612.jpg             99  OK
# Extracting  raw/images/ff9854f485b1b1a72e4bf479007e8a8d.jpg             99  OK
# Extracting  raw/images/ffa26d30264b279ee2348a2934f113a6.jpg             99  OK
# Extracting  raw/images/ffa5c29c3f4942748add6b8085c4b4e7.jpg             99  OK
# Extracting  raw/images/ffbb73373d9926dc99a1b4ac99e7ade7.jpg             99  OK
# Extracting  raw/images/ffbdec8087e32cf3fae7e7d00eefbae6.jpg             99  OK
# Extracting  raw/images/ffd8089216c7915c927a7203ece10f8d.jpg             99  OK
# Extracting  raw/images/ffdb2486e68ca9b12390a1dd5d64c121.jpg             99  OK
# Extracting  raw/images/ffdbbc2f9afb28c2741739f868c88670.jpg             99  OK
# Extracting  raw/images/ffe097c41e8ecfd403bad97ec728ab4c.jpg             99  OK
# Extracting  raw/images/ffe49f9e20bcefe4c0f6e8bc90643308.jpg             99  OK
# Extracting  raw/images/ffec05b841277940e40de657722e6892.jpg             99  OK
# Extracting  raw/images/fff53b56bb409098e9d1efd05ceba7f0.jpg             99  OK
# Extracting  raw/images/fffbfba7525d14f6ec47a870d22e447c.jpg             99  OK
# Extracting  raw/images/sample_submission.csv                            99  OK
# Extracting  raw/images/test.csv                                         99  OK
# Extracting  raw/images/train.csv                                        99  OK
# All OK

# %% [markdown]
# # Imports

# %%
import os
import glob
import pandas as pd
import shutil
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import torch
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
if os.path.exists('./dataset'):
  shutil.rmtree('./dataset')
os.mkdir('./dataset')
os.mkdir('./dataset/train')
os.mkdir('./dataset/val')
os.mkdir('./dataset/test')

# %% [markdown]
# # Split data : train / val / test

# %%
images_dir = './raw/images'
train_dir = './dataset/train/images'
val_dir = './dataset/val/images'
test_dir = './dataset/test/images'

# shutil.move(os.path.join(images_dir, 'train.csv'), os.path.join('./raw', 'train.csv'))
# shutil.move(os.path.join(images_dir, 'test.csv'), os.path.join('./raw', 'test.csv'))


train_df = pd.read_csv('./raw/train.csv')
train_df = train_df.sample(frac=1)
test_df = pd.read_csv('./raw/test.csv')


if os.path.exists(train_dir):
    shutil.rmtree(train_dir)

os.mkdir(train_dir)

for image in train_df.image_path.unique():
    shutil.copyfile(os.path.join(images_dir, image), os.path.join(train_dir, image))
    

if os.path.exists(test_dir):
    shutil.rmtree(test_dir)

os.mkdir(test_dir)

for image in test_df.image_path.unique():
    shutil.copyfile(os.path.join(images_dir, image), os.path.join(test_dir, image))

if os.path.exists(val_dir):
    shutil.rmtree(val_dir)

os.mkdir(val_dir)

train_images = os.listdir(train_dir)
val_images = train_images[len(train_images) - int(len(train_images) * 0.33) : ]
for image in val_images:
    shutil.move(os.path.join(train_dir, image), os.path.join(val_dir, image))

val_df = train_df[train_df.image_path.isin(val_images)]
train_df = train_df[~train_df.image_path.isin(val_images)]

val_df = val_df.reset_index()
train_df = train_df.reset_index()

del val_df['index']
del train_df['index']

# %% [markdown]
# # Change  scales

# %%
for image in train_df.image_path.unique():
    path = Image.open(os.path.join(train_dir, image))
    new_image = path.resize((960, 540))
    new_image.save(os.path.join(train_dir, image))
    
for image in val_df.image_path.unique():
    path = Image.open(os.path.join(val_dir, image))
    new_image = path.resize((960, 540))
    new_image.save(os.path.join(val_dir, image))

for image in test_df.image_path.unique():
    path = Image.open(os.path.join(test_dir, image))
    new_image = path.resize((960, 540))
    new_image.save(os.path.join(test_dir, image))

# %% [markdown]
# # Get classes

# %%
check_6_class = val_df[val_df['class']==6]
if len(check_6_class) > 0:
    image_path = check_6_class.image_path.values[0]
    train_df = pd.concat([train_df,check_6_class])
    val_df = val_df[val_df['class'] != 6]
    shutil.move(os.path.join(val_dir, image_path), os.path.join(train_dir,image_path))

# %%
classes = train_df.drop_duplicates('name').sort_values(by='class').reset_index()
classes = classes[['name', 'class']]
classes
# Out:
#                  name  class
# 0            GRAFFITI    0.0
# 1       FADED_SIGNAGE    1.0
# 2            POTHOLES    2.0
# 3             GARBAGE    3.0
# 4   CONSTRUCTION_ROAD    4.0
# 5      BROKEN_SIGNAGE    5.0
# 6     BAD_STREETLIGHT    6.0
# 7       BAD_BILLBOARD    7.0
# 8        SAND_ON_ROAD    8.0
# 9    CLUTTER_SIDEWALK    9.0
# 10      UNKEPT_FACADE   10.0

# %%
classes_context = '['
for c in classes['name'].values:
    classes_context =  classes_context +  "'" + c + "', "
classes_context = classes_context[:-2]
classes_context = classes_context + ']'
classes_context
# Out:
# "['GRAFFITI', 'FADED_SIGNAGE', 'POTHOLES', 'GARBAGE', 'CONSTRUCTION_ROAD', 'BROKEN_SIGNAGE', 'BAD_STREETLIGHT', 'BAD_BILLBOARD', 'SAND_ON_ROAD', 'CLUTTER_SIDEWALK', 'UNKEPT_FACADE']"

# %% [markdown]
# # Convert to yolo

# %%
def fix_dims(value):
    output = value
    if value > 1:
        output = 1
    if value < 0:
        output = 0
    return output

# %%
def convert_dimensions(path=train_dir, df=train_df):
    xs = [] 
    ys = [] 
    ws = [] 
    hs = []
    heights = []
    widths = []
    
    df = df.reset_index()
    for i in df.index:
        image = Image.open(os.path.join(path,df.iloc[i].image_path))
        height = image.height
        width = image.width
        
        xmax = df.iloc[i].xmax #* 2
        xmin = df.iloc[i].xmin #* 2
        ymax = df.iloc[i].ymax #* 2
        ymin = df.iloc[i].ymin #* 2
        
        dw = 1 / width
        dh = 1 / height
        x = (xmin + xmax) / 2 - 1
        y = (ymin + ymax) / 2 - 1
        w = xmax - xmin
        h = ymax - ymin
        x = x*dw
        w = w*dw
        y = y*dh
        h = h*dh
        
        xs.append(fix_dims(x))
        ys.append(fix_dims(y))
        ws.append(fix_dims(w))
        hs.append(fix_dims(h))
        
        heights.append(height)
        widths.append(width)
    
    return (xs, ys, ws, hs, widths, heights)

# %%
#train_df = pd.read_csv('./raw/train.csv')
train_df.ymin = train_df.ymin #* 2
train_df.ymax = train_df.ymax #* 2
train_df.xmin = train_df.xmin #* 2
train_df.xmax = train_df.xmax #* 2
new_training_dimensions = convert_dimensions()


train_df['x'] = new_training_dimensions[0]
train_df['y'] = new_training_dimensions[1]
train_df['w'] = new_training_dimensions[2]
train_df['h'] = new_training_dimensions[3]

train_df['width'] = new_training_dimensions[4]
train_df['height'] = new_training_dimensions[5]

train_df.head()
# Out:
#    class                            image_path               name   xmax  \
# 0    9.0  21df324cc8e6ce2e7275c3f081eb4d3f.jpg   CLUTTER_SIDEWALK  454.0
# 1    3.0  35ca0b579a9c3b9338d0fbadf9de540e.jpg            GARBAGE  515.0
# 2    3.0  7786324159a726ad4503418665a86e65.jpg            GARBAGE  243.0
# 3    4.0  2d660bb5f4a72e7f4edadb8774c8684e.jpg  CONSTRUCTION_ROAD  625.0
# 4    3.0  a0c9dbab6822ff3730fb4b6c3b7a819a.jpg            GARBAGE  819.0
#
#     xmin   ymax   ymin         x         y         w         h  width  height
# 0   79.0  343.0  228.0  0.276562  0.526852  0.390625  0.212963    960     540
# 1  434.0  233.0  178.0  0.493229  0.378704  0.084375  0.101852    960     540
# 2   98.0  284.0  208.0  0.176563  0.453704  0.151042  0.140741    960     540
# 3  -99.0  640.0  -41.0  0.272917  0.552778  0.754167  1.000000    960     540
# 4  707.0  307.0  256.0  0.793750  0.519444  0.116667  0.094444    960     540

# %%
val_df.ymin = val_df.ymin #* 2
val_df.ymax = val_df.ymax #* 2
val_df.xmin = val_df.xmin #* 2
val_df.xmax = val_df.xmax #* 2
new_val_dimensions = convert_dimensions(path=val_dir, df=val_df)

val_df['x'] = new_val_dimensions[0]
val_df['y'] = new_val_dimensions[1]
val_df['w'] = new_val_dimensions[2]
val_df['h'] = new_val_dimensions[3]

val_df['width'] = new_val_dimensions[4]
val_df['height'] = new_val_dimensions[5]

val_df.head()
# Out:
# <ipython-input-25-9d2299c62ba8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df.ymin = val_df.ymin #* 2
# <ipython-input-25-9d2299c62ba8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df.ymax = val_df.ymax #* 2
# <ipython-input-25-9d2299c62ba8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df.xmin = val_df.xmin #* 2
# <ipython-input-25-9d2299c62ba8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df.xmax = val_df.xmax #* 2
# <ipython-input-25-9d2299c62ba8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['x'] = new_val_dimensions[0]
# <ipython-input-25-9d2299c62ba8>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['y'] = new_val_dimensions[1]
# <ipython-input-25-9d2299c62ba8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['w'] = new_val_dimensions[2]
# <ipython-input-25-9d2299c62ba8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['h'] = new_val_dimensions[3]
# <ipython-input-25-9d2299c62ba8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['width'] = new_val_dimensions[4]
# <ipython-input-25-9d2299c62ba8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['height'] = new_val_dimensions[5]
#    class                            image_path               name   xmax  \
# 0    3.0  216452f64431c8fe0406182e99342ad1.jpg            GARBAGE  295.0
# 1    4.0  33d925a91a963db5a66ddb35be6816ad.jpg  CONSTRUCTION_ROAD  812.0
# 2    7.0  87afa33b534383babfe5ecdb3bc16b38.jpg      BAD_BILLBOARD  575.0
# 3    2.0  129e29a349f478142a5e508e4987759c.jpg           POTHOLES  784.0
# 4    3.0  a30f31d048e824cf318e22435d955fb4.jpg            GARBAGE  678.0
#
#     xmin   ymax   ymin         x         y         w         h  width  height
# 0  -25.0  356.0  149.0  0.139583  0.465741  0.333333  0.383333    960     540
# 1  397.0  343.0  147.0  0.628646  0.451852  0.432292  0.362963    960     540
# 2  437.0   36.0   -4.0  0.526042  0.027778  0.143750  0.074074    960     540
# 3  607.0  388.0  289.0  0.723437  0.625000  0.184375  0.183333    960     540
# 4  559.0  450.0  354.0  0.643229  0.742593  0.123958  0.177778    960     540

# %% [markdown]
# # Object detection (random)

# %%
def object_detection_random(df=train_df, path=train_dir, count=1):
    counter = 0 
    df = df.sample(frac=1)
    for image_path in df.image_path.unique():
        select_df = df[df.image_path == image_path].reset_index()
        del select_df['index']
        
        image = cv2.cvtColor(cv2.imread(os.path.join(path, image_path)), cv2.COLOR_BGR2RGB)
        for i in select_df.index:
            xmin = select_df.iloc[i].xmin 
            ymin = select_df.iloc[i].ymin 
            xmax = select_df.iloc[i].xmax 
            ymax = select_df.iloc[i].ymax 
            height = select_df.iloc[i].height
            width = select_df.iloc[i].width
            label = select_df.iloc[i]['name']
            
            print('class:' , select_df.iloc[i]['name'])
            print('xmin:' , xmin)
            print('ymin:' , ymin)
            print('xmax:' , xmax)
            print('ymax:' , ymax)
            print('----------------------------')
            
            cv2.rectangle(image,
                          (int(xmin) , int(ymin) ),
                          (int(xmax) , int(ymax) ),
                          (0,255,0), thickness=2)
            
            ((label_width, label_height), _) = cv2.getTextSize(label, fontFace=cv2.FONT_HERSHEY_PLAIN, 
            fontScale=1.75, thickness=2)
            
            cv2.rectangle(
      image,
          (int(xmin) , int(ymin)),
          (int(xmin + label_width + label_width * 0.05), int(ymin + label_height + label_height * 0.25)),
          color=(255, 0, 0),
          thickness=cv2.FILLED
        )
            
            cv2.putText(
          image,
          label,
          org=(int(xmin), int(ymin + label_height + label_height * 0.25)), 
          fontFace=cv2.FONT_HERSHEY_PLAIN,
          fontScale=1.75,
          color=(255, 255, 255),
          thickness=2 )
            
            plt.imshow(image)
        
        counter = counter + 1
        if count != None and count > 0 and counter >= count:
            break

# %%
object_detection_random()
# Out:
# class: CONSTRUCTION_ROAD
# xmin: 754.0
# ymin: 117.0
# xmax: 928.0
# ymax: 174.0
# ----------------------------
# class: CONSTRUCTION_ROAD
# xmin: 479.0
# ymin: 144.0
# xmax: 669.0
# ymax: 207.0
# ----------------------------
# class: CONSTRUCTION_ROAD
# xmin: 63.0
# ymin: 160.0
# xmax: 181.0
# ymax: 215.0
# ----------------------------
# class: CONSTRUCTION_ROAD
# xmin: 605.0
# ymin: 132.0
# xmax: 828.0
# ymax: 189.0
# ----------------------------
# class: CONSTRUCTION_ROAD
# xmin: 195.0
# ymin: 152.0
# xmax: 333.0
# ymax: 212.0
# ----------------------------

# %%
object_detection_random(df=val_df, path=val_dir, count=1)
# Out:
# class: GARBAGE
# xmin: 742.0
# ymin: 224.0
# xmax: 808.0
# ymax: 267.0
# ----------------------------
# class: GARBAGE
# xmin: 240.0
# ymin: 448.0
# xmax: 505.0
# ymax: 560.0
# ----------------------------
# class: GARBAGE
# xmin: 431.0
# ymin: 184.0
# xmax: 515.0
# ymax: 267.0
# ----------------------------
# class: GARBAGE
# xmin: 846.0
# ymin: 225.0
# xmax: 919.0
# ymax: 281.0
# ----------------------------
# class: GARBAGE
# xmin: 507.0
# ymin: 195.0
# xmax: 577.0
# ymax: 252.0
# ----------------------------
# class: GARBAGE
# xmin: 752.0
# ymin: 247.0
# xmax: 843.0
# ymax: 328.0
# ----------------------------
# class: GARBAGE
# xmin: 562.0
# ymin: 392.0
# xmax: 693.0
# ymax: 492.0
# ----------------------------
# class: GARBAGE
# xmin: 468.0
# ymin: 238.0
# xmax: 543.0
# ymax: 292.0
# ----------------------------
# class: GARBAGE
# xmin: 906.0
# ymin: 256.0
# xmax: 942.0
# ymax: 290.0
# ----------------------------
# class: GARBAGE
# xmin: 661.0
# ymin: 279.0
# xmax: 733.0
# ymax: 332.0
# ----------------------------

# %% [markdown]
# # Label files

# %%
def create_labels(df=train_df, path='./dataset/train/labels'):
    
    if os.path.exists(path):
        shutil.rmtree(path)
        
    os.mkdir(path)
    
    df = df.reset_index()
    for i in df.index:
        _class = df.iloc[i]['class']
        file_name = df.iloc[i].image_path.split('.')[0] + '.txt'
        x = df.iloc[i].x
        y = df.iloc[i].y
        w = df.iloc[i].w
        h = df.iloc[i].h
        
        content = '{} {} {} {} {}\n'
        content = content.format(_class, x, y, w, h)
        
        f = open(os.path.join(path, file_name) , 'a')
        f.write(content)
        f.close()

# %%
create_labels()

# %%
create_labels(val_df, './dataset/val/labels')

# %% [markdown]
# # Download yolo

# %%
# !git clone https://github.com/ultralytics/yolov5  
# !pip install -U -r yolov5/requirements.txt
# !pip install numpy==1.21
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14998, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 14998 (delta 0), reused 0 (delta 0), pack-reused 14995
# Receiving objects: 100% (14998/14998), 14.08 MiB | 6.83 MiB/s, done.
# Resolving deltas: 100% (10286/10286), done.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gitpython
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /usr/lib/python3/dist-packages (from -r yolov5/requirements.txt (line 6)) (7.13.0)
# Collecting ipython
#   Downloading ipython-8.8.0-py3-none-any.whl (775 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 kB 107.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2.2 in ./.local/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 7)) (3.5.3)
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 139.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.18.5 in ./.local/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 8)) (1.23.4)
# Collecting numpy>=1.18.5
#   Downloading numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 124.3 MB/s eta 0:00:0000:0100:01
# Collecting opencv-python>=4.1.1
#   Downloading opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 63.0 MB/s eta 0:00:0000:0100:01
# Collecting Pillow>=7.1.2
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 148.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from -r yolov5/requirements.txt (line 11)) (5.5.1)
# Collecting psutil
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 63.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/lib/python3/dist-packages (from -r yolov5/requirements.txt (line 12)) (5.3.1)
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 113.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.23.0 in ./.local/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 13)) (2.28.1)
# Collecting requests>=2.23.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in ./.local/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 14)) (1.9.3)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 90.5 MB/s eta 0:00:0000:0100:01
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.7.0 in /usr/lib/python3/dist-packages (from -r yolov5/requirements.txt (line 16)) (1.12.1)
# Collecting torch>=1.7.0
#   Downloading torch-1.13.1-cp38-cp38-manylinux1_x86_64.whl (887.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 6.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: torchvision>=0.8.1 in /usr/lib/python3/dist-packages (from -r yolov5/requirements.txt (line 17)) (0.13.1)
# Collecting torchvision>=0.8.1
#   Downloading torchvision-0.14.1-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 104.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm>=4.64.0 in ./.local/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 18)) (4.64.1)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/lib/python3/dist-packages (from -r yolov5/requirements.txt (line 22)) (2.9.1)
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 156.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: pandas>=1.1.4 in ./.local/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 27)) (1.5.1)
# Collecting pandas>=1.1.4
#   Downloading pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 128.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: seaborn>=0.11.0 in ./.local/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 28)) (0.12.1)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 69.5 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 20.4 MB/s eta 0:00:00
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 136.5 MB/s eta 0:00:00
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 6)) (4.6.0)
# Requirement already satisfied: backcall in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: pygments>=2.4.0 in ./.local/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (2.13.0)
# Collecting prompt-toolkit<3.1.0,>=3.0.11
#   Downloading prompt_toolkit-3.0.36-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 kB 79.6 MB/s eta 0:00:00
# Collecting stack-data
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/lib/python3/dist-packages (from ipython->-r yolov5/requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: traitlets>=5 in ./.local/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (5.5.0)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 67.7 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in ./.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (2.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (2019.11.28)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.8/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (1.25.8)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 122.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 9.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in ./.local/lib/python3.8/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 16)) (4.4.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 119.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 16.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->-r yolov5/requirements.txt (line 16)) (45.2.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->-r yolov5/requirements.txt (line 16)) (0.34.2)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 65.7 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (3.11.4)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 119.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (0.15.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (1.29.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (0.4.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.8/177.8 kB 49.4 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 162.2 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.8/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2022.5)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (0.2.1)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (1.14.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (4.0.0)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth in /usr/lib/python3/dist-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython->-r yolov5/requirements.txt (line 6)) (0.1.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (2.1.1)
# Collecting executing>=1.2.0
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Installing collected packages: tensorboard-plugin-wit, pure-eval, executing, werkzeug, tensorboard-data-server, smmap, requests, PyYAML, psutil, prompt-toolkit, Pillow, parso, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, matplotlib-inline, google-auth, asttokens, tensorboard, stack-data, scipy, pandas, opencv-python, nvidia-cudnn-cu11, jedi, gitdb, contourpy, torch, matplotlib, ipython, gitpython, torchvision, thop, seaborn
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.1
#     Uninstalling pandas-1.5.1:
#       Successfully uninstalled pandas-1.5.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.3
#     Uninstalling matplotlib-3.5.3:
#       Successfully uninstalled matplotlib-3.5.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.1
#     Uninstalling seaborn-0.12.1:
#       Successfully uninstalled seaborn-0.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.4.0 requires matplotlib<3.6,>=3.2, but you have matplotlib 3.6.3 which is incompatible.
# pandas-profiling 3.4.0 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.1 which is incompatible.
# pandas-profiling 3.4.0 requires scipy<1.10,>=1.4.1, but you have scipy 1.10.0 which is incompatible.
# Successfully installed Pillow-9.4.0 PyYAML-6.0 asttokens-2.2.1 contourpy-1.0.7 executing-1.2.0 gitdb-4.0.10 gitpython-3.1.30 google-auth-2.16.0 ipython-8.8.0 jedi-0.18.2 matplotlib-3.6.3 matplotlib-inline-0.1.6 numpy-1.24.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 opencv-python-4.7.0.68 pandas-1.5.3 parso-0.8.3 prompt-toolkit-3.0.36 psutil-5.9.4 pure-eval-0.2.2 requests-2.28.2 scipy-1.10.0 seaborn-0.12.2 smmap-5.0.0 stack-data-0.6.2 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 thop-0.1.1.post2209072238 torch-1.13.1 torchvision-0.14.1 werkzeug-2.2.2
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==1.21
#   Downloading numpy-1.21.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 130.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Successfully uninstalled numpy-1.24.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.4.0 requires matplotlib<3.6,>=3.2, but you have matplotlib 3.6.3 which is incompatible.
# pandas-profiling 3.4.0 requires scipy<1.10,>=1.4.1, but you have scipy 1.10.0 which is incompatible.
# Successfully installed numpy-1.21.0
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# # Create config files

# %%
dataset_config_text = """train: {}
val : {}
nc: {}
names: {}
"""

dataset_config_text = dataset_config_text.format('../' + train_dir, '../' + val_dir, classes['name'].nunique(), classes_context)

f = open('./yolov5/dataset_config.yaml', 'w')
f.write(dataset_config_text)
f.close()

# %%
model_config_text = """# parameters
nc: {}  # number of classes  # CHANGED HERE
depth_multiple: 0.33  # model depth multiple
width_multiple: 0.50  # layer channel multiple

# anchors
anchors:
  - [10,13, 16,30, 33,23]  # P3/8
  - [30,61, 62,45, 59,119]  # P4/16
  - [116,90, 156,198, 373,326]  # P5/32

# YOLOv5 backbone
backbone:
  # [from, number, module, args]
  [[-1, 1, Focus, [64, 3]],  # 0-P1/2
   [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
   [-1, 3, BottleneckCSP, [128]],
   [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
   [-1, 9, BottleneckCSP, [256]],
   [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
   [-1, 9, BottleneckCSP, [512]],
   [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
   [-1, 1, SPP, [1024, [5, 9, 13]]],
   [-1, 3, BottleneckCSP, [1024, False]],  # 9
  ]

# YOLOv5 head
head:
  [[-1, 1, Conv, [512, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 6], 1, Concat, [1]],  # cat backbone P4
   [-1, 3, BottleneckCSP, [512, False]],  # 13

   [-1, 1, Conv, [256, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 4], 1, Concat, [1]],  # cat backbone P3
   [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)

   [-1, 1, Conv, [256, 3, 2]],
   [[-1, 14], 1, Concat, [1]],  # cat head P4
   [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)

   [-1, 1, Conv, [512, 3, 2]],
   [[-1, 10], 1, Concat, [1]],  # cat head P5
   [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)

   [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
  ]
"""

model_config_text = model_config_text.format(classes['name'].nunique())

f = open('./yolov5/model_config.yaml', 'w')
f.write(model_config_text)
f.close()

# %% [markdown]
# # Train model

# %%
# !python yolov5/train.py --img 960  --epochs 50 --data yolov5/dataset_config.yaml --weights yolov5/yolov5l.pt --cache --workers 16
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# train: weights=yolov5/yolov5l.pt, cfg=, data=yolov5/dataset_config.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=960, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=16, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA A100-SXM4-40GB, 40396MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# --------------------------------------------------------------------------
# WARNING: No preset parameters were found for the device that Open MPI
# detected:
#
#   Local host:            141-148-194-249
#   Device name:           mlx5_0
#   Device vendor ID:      0x02c9
#   Device vendor part ID: 4126
#
# Default device parameters will be used, which may result in lower
# performance.  You can edit any of the files specified by the
# btl_openib_device_param_files MCA parameter to set values for your
# device.
#
# NOTE: You can turn off this warning by setting the MCA parameter
#       btl_openib_warn_no_device_params_found to 0.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# No OpenFabrics connection schemes reported that they were able to be
# used on a specific port.  As such, the openib BTL (OpenFabrics
# support) will be disabled for this port.
#
#   Local host:           141-148-194-249
#   Local device:         mlx5_0
#   Local port:           1
#   CPCs attempted:       udcm
# --------------------------------------------------------------------------
# Overriding model.yaml nc=80 with nc=11
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     86160  models.yolo.Detect                      [11, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary: 368 layers, 46192144 parameters, 46192144 gradients, 108.4 GFLOPs
#
# Transferred 607/613 items from yolov5/yolov5l.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 101 weight(decay=0.0), 104 weight(decay=0.0005), 104 bias
# train: Scanning /home/ubuntu/dataset/train/labels.cache... 5277 images, 0 backgr
# train: Caching images (7.6GB ram): 100%|██████████| 5277/5277 [00:03<00:00, 1455
# val: Scanning /home/ubuntu/dataset/val/labels.cache... 2597 images, 0 background
# val: Caching images (3.8GB ram): 100%|██████████| 2597/2597 [00:02<00:00, 1058.4
#
# AutoAnchor: 4.57 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/exp2/labels.jpg...
# Image sizes 960 train, 960 val
# Using 16 dataloader workers
# Logging results to yolov5/runs/train/exp2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      19.3G    0.07558    0.05275    0.03894         68        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.514      0.209     0.0638     0.0187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      20.2G    0.06267    0.04302    0.01645         67        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.493      0.337      0.206     0.0743
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49      20.2G    0.05892     0.0415    0.01233         46        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.506      0.281      0.207     0.0733
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49      20.2G    0.05596     0.0427    0.01143         63        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.466      0.267       0.19     0.0657
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49      20.2G    0.05416    0.04259    0.01048         73        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.378      0.349      0.239     0.0897
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49      20.2G    0.05214    0.04228   0.009672         65        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.416      0.367      0.288      0.109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49      20.2G    0.05143    0.04136   0.008733         79        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.426      0.374      0.324      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49      20.2G    0.05015    0.04014   0.008061         71        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0.389      0.391      0.336      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49      20.2G    0.04937     0.0397   0.007642         54        960: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2597       6558      0